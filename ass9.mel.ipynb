# %% [markdown]
# # Applied Data Science Capstone Week 4 Peer-Graded Assignment

# %% [markdown]
# ## Week 4 Peer-Graded Assignment

# %%
from PIL import Image
import requests
url = 'https://www.melbourne.vic.gov.au/SiteCollectionImages/CoM-2019-20-budget-460.jpg'
im = Image.open(requests.get(url, stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=460x440 at 0x1F0E5E66D30>

# %% [markdown]
# ## Introduction to the opportunity

# %% [markdown]
# ### Fredericton is the capital of the Canadian province of New Brunswick. The city is situated in the west-central portion of the province along the Saint John River, which flows west to east as it bisects the city. The river is the dominant natural feature of the area. One of the main urban centres in New Brunswick, the city had a population of 58,220 in the 2016 Canadian Census. It is the third-largest city in the province after Moncton and Saint John.
#
# ### An important cultural, artistic, and educational centre for the province, Fredericton is home to two universities, the New Brunswick College of Craft and Design, and cultural institutions such as the Beaverbrook Art Gallery, the Fredericton Region Museum, and The Playhouse, a performing arts venue. The city hosts the annual Harvest Jazz & Blues Festival, attracting regional and international jazz, blues, rock, and world artists. Fredericton is also an important and vibrant centre point for the region's top visual artists; many of New Brunswick's notable artists live and work there today. Fredericton has also been home to some great historical Canadian painters as well, including Goodridge Roberts, and Molly and Bruno Bobak.
#
# ### As a provincial capital, its economy is tied to the public sector; however, the city also contains a growing IT and commercial sector. The city has the highest percentage of residents with post-secondary education in the province and the highest per capita income of any city in New Brunswick.
#
# ### Developers, policy makers and/or city planners have an interest in answering the following questions:
#
# ### **1.Which neighbourhoods has the highest crime rate?**
# ### **2.Does population density correlate with crime levels?**
# ### **3.Distance from primary and secondary schools**
# ### **4.Trolley operation law**

# %% [markdown]
# ## Data
# ### To understand and explore we will need the following City of Fredericton Open Data:
# ### Open Data Site: http://data-fredericton.opendata.arcgis.com/
# ### Fredericton Neighbourhoods: http://data-fredericton.opendata.arcgis.com/datasets/neighbourhoods--quartiers
# ### Fredericton Crime by Neighbourhood: http://data-fredericton.opendata.arcgis.com/datasets/crime-by-neighbourhood-2017--crime-par-quartier-2017
# ### Fredericton Census Tract Demographics: http://data-fredericton.opendata.arcgis.com/datasets/census-tract-demographics--donn%C3%A9es-d%C3%A9mographiques-du-secteur-de-recensement
# ### Fredericton locations of interest: https://github.com/JasonLUrquhart/Applied-Data-Science-Capstone/blob/master/Fredericton%20Locations.xlsx
# ### Foursquare Developers Access to venue data: https://foursquare.com/
# ### The data can be explored and tested to answer questions. Community data will allow us to correctly group crimes by community. Census data will allow us to compare population density to see if the areas with the highest crime rates are also the most densely populated. The site of Fredericton's interest will then allow us to gather and quantify the most common locations of the site.

# %% [markdown]
# ## Methodology
# ### The methodology will include:
#
# ### Loading the data set  above
# ### Examine the crime frequency in each neighbourhood
# ### Through the research of community crime types, the frequency of neighbourhood crime types is analyzed by principal component
# ### Understand correlation between crimes and population density
# ### Perform k-means statisical analysis on venues by locations of interest based on findings from crimes and neighbourhood
# ### Determine which venues are most common statistically in the region of greatest crime count then in all other locations of interest.
# ### Determine if  the Knowledge Park needs a coffee shop.

# %% [markdown]
# ## Loading the data
# ### After the applicable libraries are loaded, the referenced geojson adjacent data is loaded from the Fredericton city open data site. The dataset USES block polygon shape coordinates for easy visualization and comparison. Cities also use Ward data, but neighborhood location data is more accurate and contains more detail. The same type of data set was then loaded from the Stats Canada census to represent population density
#
# ### The third dataset is an excel file that was downloaded from the Fredericton city open data website and "neighborhood crime 2017" was found in the area of public safety. The dataset is then uploaded for analysis. It is worth noting that the details of this dataset are aggregated by neighbor. It is not an exhaustive collection, and does not include all crimes (violent crimes) or specific location data for crimes, but is cited by neighbors.
#
# ### This means that we can know the number of crimes by type and by region, but not enough to know the distribution. Valuable questions, such as "did these crimes occur in a specific area, at a specific time, and with a specific group of people?" These questions cannot be answered or explored because there is reason to believe that the information is personal and private with legal risks.
#
# ### There is value to the city to explore the detailed crime data using data science to predict frequency, location, timing and conditions to best allocated resources for the benefit of its citizens and it's police force. However, human behaviour is complex requiring thick profile data by individual and the conditions surrounding the event(s). To be sufficient for reliable future prediction it would need to demonstrate validity, currency, reliability and sufficiency.

# %% [markdown]
# ##  Exploring the data
# ### Through the investigation of neighborhood crime, we can get a preliminary understanding of the distribution of crime.
#
# ### It's worth noting that adjacent names can change at different times. The crime dataset does not mention which specific neighborhood named dataset it USES, but we assume that the neighborhood data provided is the same as the neighborhood used in the crime data. It may be useful to note the city and timestamp the neighborhood naming in the future or just refer to the neighborhood naming file, which is used for the crime dataset.
#
# ### An example of a data error: an error was found in the name of the adjacent "Platt". The neighborhood data is shown as "Plat," while the crime data is shown as "Platt." Since the crime dataset was the easiest to manipulate, it was modified to "Plat." The real name of the neighborhood is "pratt."

# %% [markdown]
# ## Crime visualization
# ### Once the data is ready, a map of choropleth is created to look at crime in each neighborhood. Unsurprisingly, the areas with the highest crime rates were the city centre and platt.
#
# ### By analyzing the types of crimes, we can understand the most common types of crimes, and then use a bar chart to depict the most common types of crimes.
#
# ### Car theft is the most common crime in the same area. It's worth noting that the area is mostly residential, with no garages. Further research is needed on whether monitoring in urban centers can deter motor vehicle crime compared to the low level of monitoring in the pratt area.

# %% [markdown]
# ### After studying pivottometers that show the types of neighborhood crimes, we delve into specific types of crime, stealing cars, and mapping the choropleth to see which areas have the highest frequency.
#
# ### Also, the pratt community seems to be the most frequent.

# %% [markdown]
# ### The relationship between crime rate and population density is discussed by using census data.
# ### By visualizing the population density, we were able to determine that the pratt community was less associated with crime than I had expected.
#
# ### It would be interesting to study the census data further if it included people who rent or stay temporarily, assuming the city is a university center.

# %% [markdown]
# ### Look at specific locations to see how they relate to venues using Foursquare data
# ### Loading the "Fredericton site" data allows us to perform statistical analysis of the most common sites by location.
#
# ### We might wonder if the prevalence of bars and clubs in the downtown area is related to the higher crime rate in the area around the pratt.
#
# ### By mapping the latitude and longitude coordinates of the locations of interest onto a crime map, we can now use Foursquare data to study the most common locations.

# %% [markdown]
# ## Analyze each of the positions
# ### Grouped by location and the average frequency of each category, we looked at the five most common sites in the location category.
#
# ### By putting this data into the panda dataframe, we can determine the most common places by location and drawing on the map.

# %% [markdown]
# ## Results

# %% [markdown]
# ### Analysis enables us to discover and describe visualizations and quantifications:
#
# ### It was in the Fredericton neighborhood
#
# ### Neighborhood crime frequency
#
# ### Crime types, frequency and statistics. The average crime rate in Fredericton is 22.
#
# ### Crime types are counted by block.
# ### Car theft is the most common crime in the same area. It's worth noting that the area is mostly residential, with no garages. Further research is needed on whether monitoring in urban centers can deter motor vehicle crime compared to the low level of monitoring in the pratt area.

# %% [markdown]
# ### 1. Motor vehicle crimes less than 5,000 were statistically analysed by neighbourhood and results.
# ### The most common crime is other theft less than 5,000, followed by motor vehicle theft less than 5,000. The city has an average of six motor vehicle burglaries every five kilometers.
#
# ### 2. Population density and the resulting visual correlation were not strongly correlated with crime frequency. The cause of the crime is uncertain due to the lack of specificity of publicly available data on individuals and circumstances.
#
# ### 3.Using k-menas, we were able to identify 10 of the most common sites within a 1-kilometer radius of the center of a high-crime area. In neighborhoods with the highest crime rates, the most common venues are coffee shops, followed by bars and bars.

# %% [markdown]
# ### While, it is not valid, consistent, reliable or sufficient to assume a higher concentration of the combination of coffee shops, bars and clubs predicts the amount of crime occurance in the City of Fredericton, this may be a part of the model needed to be able to in the future.
#
# ### We were able to determine the top 10 most common venues by location of interest.
#
# ### Statisically, we determined there are no coffee shops within the Knowledge Park clusters

# %% [markdown]
# ## Discussion and Recommendations

# %% [markdown]
# ### The city's public data allow us to understand the number of crimes by type and region, but are not specific enough to understand their distribution characteristics. Valuable questions, such as "did these crimes occur in a specific area, at a specific time, and with a specific group of people?" These questions cannot be answered or explored because there is reason to believe that the information is personal and private with legal risks.
#
# ### It is valuable for cities to study detailed crime data, using data science to predict the frequency, location, timing and conditions of crime to provide the best allocation of resources for citizens and police. However, human behavior is complex and requires a large amount of personal data and conditions surrounding the event. To make future predictions reliable enough, they need to prove validity, currency, reliability and sufficiency.

# %% [markdown]
# ### It's worth noting that the neighborhood's name may change. The crime dataset does not mention which specific neighborhood named dataset it USES, but we assume that the neighborhood data provided is the same as the neighborhood used in the crime data. It may be useful to note the city and timestamp the neighborhood naming in the future or just refer to the neighborhood naming file, which is used for the crime dataset.
#
# ### There is an error in the current open data. The nearby "platt" was misnamed. The neighborhood data is shown as "Plat," while the crime data is shown as "Platt." Since the crime dataset was the easiest to manipulate, it was modified to "Plat." The real name of the neighborhood is "pratt."

# %% [markdown]
# ### Car theft is the most common crime in the same area. It's worth noting that the area is mostly residential, with no garages. Further research is needed on whether monitoring in urban centers can deter motor vehicle crime compared to the low level of monitoring in the pratt area.
#
# ### It would be interesting to study the census data further, if it included people who rent or live temporarily/temporarily, assuming the city is a university center.
#
# ### According to a survey of the top 10 most common locations of interest, knowledge park has no coffee shops among the top 10 most common locations identified by the Foursquare dataset. Given that the area has the highest concentration of shops and stores, coffee shops are good for Fredericton's business community and citizens.

# %% [markdown]
# ## conclusion
# ### By combining data sets from the Fredericton open data project and Foursquare location data, we were able to analyze, discover, and describe nearby communities, crime, population density, and statistically describe locations of interest.
#
# ### While the Fredericton city open data is interesting overall, it ignores the details needed for truly valuable quantitative and predictive analysis that investors and developers value most in order to make appropriate investments and minimize risk.
#
# ### The open data project is a good start in making possible the "citizen like me" model, in which the citizens of digital Fredericton can share their data because they want detailed analysis to create valuable services.
